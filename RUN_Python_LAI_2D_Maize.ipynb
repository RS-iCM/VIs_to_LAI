# %%
### Emprical function to estimate LAI using VIs
from codes.empirical_VIs_to_LAI_2D_Maize import main
import os
cwd = os.getcwd()
maize_data_dir = cwd + '/class_map_maize_Iowa/'
output_dir = cwd + '/outputs/py_LAI_VIs_maize_Iowa/'  
map_dir = cwd + '/USA_Iowa_Map/USA_IA_UTM15N.shp'
IO_file_path = 'info_Read_RS_VIs_n_Out_LAI_Maize.inp'

main(cwd, maize_data_dir, output_dir, map_dir, IO_file_path)
# Out:
# /home/jko/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Run = 0 / 2
# Run = 1 / 2
# Run = 2 / 2
# Data saved to /data/Python_Project/RSCM_Python/VIs_to_LAI_crops_2D/outputs/py_LAI_VIs_maize_Iowa/2012_Mean_LAI.txt
# mean: 1.274
