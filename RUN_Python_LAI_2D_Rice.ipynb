# %%
### Emprical function to estimate LAI using VIs
from codes.empirical_VIs_to_LAI_2D_Rice import main
import os
cwd = os.getcwd()
paddy_data_dir = cwd + '/class_map_rice_Paju/'
output_dir = cwd + '/outputs/py_LAI_VIs_rice_Paju/'  
map_dir = cwd + '/Shape_Paju_SK/Paju.shp'
IO_file_path = 'info_Read_RS_VIs_n_Out_LAI_Rice.inp'

main(cwd, paddy_data_dir, output_dir, map_dir, IO_file_path)
# Out:
# Run = 0 / 5
# Run = 1 / 5
# Run = 2 / 5
# Run = 3 / 5
# Run = 4 / 5
# Run = 5 / 5
# Data saved to /data/Python_Project/RSCM_Python/VIs_to_LAI_crops_2D/outputs/py_LAI_VIs_rice_Paju/2022_Mean_LAI.txt
# mean: 2.053

# %%
### Emprical function to estimate LAI using VIs
from codes.empirical_log_VIs_to_log_LAI_2D_Rice import main
import os
cwd = os.getcwd()
paddy_data_dir = cwd + '/class_map_rice_Paju/'
output_dir = cwd + '/outputs/py_LAI_VIs_rice_Paju/'  
map_dir = cwd + '/Shape_Paju_SK/Paju.shp'
fdata = 'data/VIs_LAI_Whole_rice.OBS'
IO_file_path = 'info_Read_RS_VIs_n_Out_LAI_Rice.inp'

main(cwd, paddy_data_dir, output_dir, map_dir, fdata, IO_file_path)
# Out:
# Run = 0 / 5
# Run = 1 / 5
# Run = 2 / 5
# Run = 3 / 5
# Run = 4 / 5
# Run = 5 / 5
# Data saved to /data/Python_Project/RSCM_Python/VIs_to_LAI_crops_2D/outputs/py_LAI_VIs_rice_Paju/2022_Mean_LAI.txt
# mean: 6.280

# %%
### Emprical function to estimate LAI using VIs
#%run codes/ET_sim_Rice_LAI_from_VIs.py

# %%
### Emprical function to estimate LAI using VIs
from codes.empirical_ET_VIs_to_LAI_2D_Rice import main
import os
cwd = os.getcwd()
paddy_data_dir = cwd + '/class_map_rice_Paju/'
output_dir = cwd + '/outputs/py_LAI_VIs_rice_Paju/'  
map_dir = cwd + '/Shape_Paju_SK/Paju.shp'
IO_file_path = 'info_Read_RS_VIs_n_Out_LAI_Rice.inp'
pkl_filename = 'models/pickle_extra_trees_Rice.pkl'  # Load ML model from file

main(cwd, paddy_data_dir, output_dir, map_dir, IO_file_path, pkl_filename)
# Out:
# /home/jko/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Run = 0 / 5
# Run #500
# Run = 1 / 5
# Run #500
# Run = 2 / 5
# Run #500
# Run = 3 / 5
# Run #500
# Run = 4 / 5
# Run #500
# Run = 5 / 5
# Run #500
# Data saved to /data/Python_Project/RSCM_Python/VIs_to_LAI_crops_2D/outputs/py_LAI_VIs_rice_Paju/2022_Mean_LAI.txt
# mean: 3.356
